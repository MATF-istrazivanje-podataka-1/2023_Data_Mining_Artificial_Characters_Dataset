# %% [markdown]
# # K Means algorithm and Agglomerative Clustering - Comparison

# %%
import matplotlib.pyplot as plt

# Load and display the image
K_means = plt.imread('k_means.png')
Aggl = plt.imread('aggl.png')

# %%
fig = plt.figure(figsize=(20, 18))  # Adjust the width and height as desired

plt.imshow(K_Means)
plt.title("K Means Clusters")
plt.axis('off')
plt.show()

fig = plt.figure(figsize=(20, 18))  # Adjust the width and height as desired

plt.imshow(Aggl)
plt.title("Agglomerative Clusters")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Low-Rated Dominant Clusters: Comparison
#
# First, we are going to compare Cluster 2 from K-Means and Cluster 1 from Agglomerative models.
#
# |                          | <b>Low Rated</b> | Medium Rated | High Rated |
# |--------------------------|-----------|--------------|------------|
# |K Means     | <b>37.7%     | 32.4%        | 29.9%      |
# |Agglomerative| <b>43%       | 40.2%        | 16.8%      |
#
# Even though the Agglomerative model has a larger percentage of Low-Rated titles, the difference between the Low and Medium rated titles is larger with this model.
# However, the K-means model has almost twice as big percentage of High-Rated titles, which I believe is a bigger issue.
#
# The <b>Agglomerative<b> model is more efficient in this case.

# %% [markdown]
# ### Medium-Rated Dominant Clusters: Comparison
#
# Next, we are going to compare Cluster 1 from K-Means and Cluster 3 from Agglomerative models.
#
# |                          | Low Rated | <b>Medium Rated | High Rated |
# |--------------------------|-----------|--------------|------------|
# |K Means     | 38%     | <b>46.2%        | 15.9%      |
# |Agglomerative| 26.1%       |  <b>35.2%        | 38.7%      |
#
# The Agglomerative model doesn't actually have a Medium-rated dominant cluster. We compared it to Cluster 3 because Cluster 2 is more High-Rated dominant.
#
# The <b>K Means</b> model is more efficient in this case.

# %% [markdown]
# ### Medium-Rated Dominant Clusters: Comparison
#
# Next, we are going to compare Cluster 3 from K-Means and Cluster 2 from Agglomerative models.
#
# |                          | Low Rated | Medium Rated | <b>High Rated |
# |--------------------------|-----------|--------------|------------|
# |K Means     | 17.1%     | 22.9%        | <b>60%      |
# |Agglomerative| 17.2%       |  23.2%        | <b>59.6%      |
#
# The K Means is slightly better.
#
# The <b>K Means</b> model is more efficient in this case.

# %% [markdown]
# ## Sihlouette scores
#
# - K- means algorithm has this average sihlouette score: 0.39665762880499467
# - Agglomerative Clustering algorithm has this average sihlouette score: 0.4191515352464625
#
# Generally, the higher sihlouette score indicates that the algorithm is more precise.

# %% [markdown]
# ## Conclusion
#
# Generally, the K means model performs better. It had better distribution of High-Rated and Medium-Rated titles, although the Agglomerative model outperforms it when it comes to the distribution Low-Rated titles.
